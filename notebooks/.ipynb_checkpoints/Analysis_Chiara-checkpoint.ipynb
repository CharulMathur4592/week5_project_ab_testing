# %% [markdown]
# ## Client behavior analysis
# **Who are the primary clients using this online process?**

# %%
# key clients in test vs control 
# primary based on the balance? 
# H1: primary clients. frequent logons, high tenure, high account balances.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
#df = %run demo_cleaning_Chiara.ipynb # access py files with magic command to see the outcome of a previous file
#df

# %%
df= pd.read_csv('final_demo_cleaned.csv') # final cleaned outcome must be saved as csv --> it must be in the same folder to be accessed and worked on 
df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age    gendr  \
# 0         836976               6                73        60  Unknown
# 1        2304905               7                94        58  Unknown
# 2        1439522               5                64        32  Unknown
# 3        1562045              16               198        49     Male
# 4        5126305              12               145        33   Female
# ...          ...             ...               ...       ...      ...
# 70604    7993686               4                56        38  Unknown
# 70605    8981690              12               148        31     Male
# 70606     333913              16               198        61   Female
# 70607    1573142              21               255        68     Male
# 70608    5602139              21               254        59   Female
#
#        num_accts         bal  calls_6_mnth  logons_6_mnth
# 0              2    45105.30             6              9
# ...
