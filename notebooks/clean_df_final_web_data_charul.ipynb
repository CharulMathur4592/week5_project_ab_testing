# %%
import pandas as pd

# %%
# Loading the Web Data Part 1 CSV file

df_web_data_pt_1 = pd.read_csv("C:/Users/Janak ARORA/Desktop/Ironhack_files/Week_5/Day1/mini_project/week5_project_ab_testing/data/raw/df_final_web_data_pt_1.txt", sep=",")
df_web_data_pt_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
# Loading the Web Data Part 2 CSV file

df_web_data_pt_2 = pd.read_csv("C:/Users/Janak ARORA/Desktop/Ironhack_files/Week_5/Day1/mini_project/week5_project_ab_testing/data/raw/df_final_web_data_pt_2.txt", sep=",")
df_web_data_pt_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
df = pd.concat([df_web_data_pt_1, df_web_data_pt_2], ignore_index=True)
df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df.isnull()
# Out:
#         client_id  visitor_id  visit_id  process_step  date_time
# 0           False       False     False         False      False
# 1           False       False     False         False      False
# 2           False       False     False         False      False
# 3           False       False     False         False      False
# 4           False       False     False         False      False
# ...           ...         ...       ...           ...        ...
# 755400      False       False     False         False      False
# 755401      False       False     False         False      False
# 755402      False       False     False         False      False
# 755403      False       False     False         False      False
# 755404      False       False     False         False      False
#
# [755405 rows x 5 columns]

# %%
df.isna().any()
# Out:
# client_id       False
# visitor_id      False
# visit_id        False
# process_step    False
# date_time       False
# dtype: bool

# %%
df.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
df["date_time"] = pd.to_datetime(df["date_time"], errors="coerce")

# %%
df.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time       datetime64[ns]
# dtype: object

# %%
df.columns = df.columns.str.replace(" ", "", regex=False)

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df.nunique()
# Out:
# client_id       120157
# visitor_id      130236
# visit_id        158095
# process_step         5
# date_time       629363
# dtype: int64

# %%
df.apply(pd.Series.unique)
# Out:
# client_id       [9988021, 8320017, 4033851, 1982004, 9294070, ...
# visitor_id      [580560515_7732621733, 39393514_33118319366, 7...
# visit_id        [781255054_21935453173_531117, 960651974_70596...
# process_step             [step_3, step_2, step_1, start, confirm]
# date_time       [2017-04-17 15:27:07, 2017-04-17 15:26:51, 201...
# dtype: object

# %%
df.columns
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], dtype='object')
